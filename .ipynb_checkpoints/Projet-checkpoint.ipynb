# %%
from PIL import Image
import numpy
import math
import time
import matplotlib.pyplot as plot
from sklearn.cluster import MiniBatchKMeans
import glob
from tqdm import tqdm_notebook as tqdm
import csv

from colormath.color_objects import sRGBColor, LabColor
from colormath.color_conversions import convert_color
from colormath.color_diff import delta_e_cie2000
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def get_pokemon_list():
    file_data = open('data.csv', 'r+') #14 éléments par pokemon chemin + 3*4(RGBA) couleurs  + taille en pixels colorés
    file_pokemon = open('pokemon.csv', 'r')

    reader_data = csv.reader(file_data,delimiter=',')
    reader_pokemon = csv.reader(file_pokemon,delimiter=',')

    list_data =  []
    list_pokemon = []

    for row in reader_data:
        list_data.append(row)

    for row in reader_pokemon:
        list_pokemon.append(row)
        
    return list_data, list_pokemon

# %%
def get_colors(imgName):
    imgfile = Image.open(imgName)
    numarray = numpy.array(imgfile.getdata(), numpy.uint8)
    cluster_count = 4

    mclusters = MiniBatchKMeans(n_clusters = cluster_count)
    mclusters.fit(numarray.reshape(-4, 4))

    npbins = numpy.arange(0, cluster_count + 1)
    histogram = numpy.histogram(mclusters.labels_, bins=npbins)
    Histsorted = sorted(histogram[0] ,reverse=True)
    labels = numpy.unique(mclusters.labels_)
    
    #Calcul des coefficients des couleurs 
    couleur_percentage = [Histsorted[i] / sum(Histsorted[1:]) for i in range(1, len(Histsorted))]

    return mclusters.cluster_centers_[1:].tolist(), couleur_percentage

# %%
def get_size(imgName):
    compteur = 0
    imgfile = Image.open(imgName)
    for i in range(imgfile.size[0]):
        for j in range(imgfile.size[1]):
            if imgfile.getpixel((i,j)) == (0,0,0,0):
                compteur += 1

    return imgfile.size[0]*imgfile.size[1] - compteur

# %%
def get_types(imgName, list_pokemon):
     #Searching types
    pokemonName = imgName[22:-4]
    for pokemon in list_pokemon:
        types = []
        if(pokemon[0] == pokemonName):
            types = pokemon[1:]
            if(len(types) < 2):
                type1 = types[0]
                type2 = ""
            else:
                type1 = types[0]
                type2 = types[1]
    return type1, type2

# %%
def get_features_list(couleurs, compteur, type1, type2, imgName, couleur_percentage):
    imagedata = []
    imagedata.append(couleurs[0])
    imagedata.append(couleurs[1])
    imagedata.append(couleurs[2])
    imagedata.append(compteur)
    imagedata.append(imgName)
    imagedata.append(couleur_percentage[0])
    imagedata.append(couleur_percentage[1])
    imagedata.append(couleur_percentage[2])
    imagedata.append(type1)
    imagedata.append(type2)
    return imagedata

# %%
def get_features_for_csv():
    
    data = []
    
    images = glob.glob("pokemon-images/images/*png")
    
    list_data, list_pokemon = get_pokemon_list()

    for imgName in tqdm(images):
        
        #Calcul des couleurs ainsi que de leur proportion
        couleurs, couleur_percentage = get_colors(imgName)

        #Calcul de la taille
        compteur = get_size(imgName)
        
        #Récupération des types
        type1, type2 = get_types(imgName, list_pokemon)
        
        #On stocke toutes les données relatives au pokemon dans une liste
        imagedata = get_features_list(couleurs, compteur, type1, type2, imgName, couleur_percentage)

        #On ajoute cette liste à la liste contenant les données de tous les pokemons
        data.append(imagedata)
        
    return data

# %%
def add_data_to_csv(data):
    
    with open('data.csv', 'w', newline='') as csvfile:
        fieldnames = ["Nom", "Couleur1.1","Couleur1.2","Couleur1.3", "Percentage1", "Couleur2.1","Couleur2.2","Couleur2.3","Percentage2", "Couleur3.1", "Couleur3.2", "Couleur3.3", "Percentage3", "Taille", "Type1", "Type2"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        for i in tqdm(data):
            writer.writerow({'Nom': i[4],
                            'Couleur1.1': i[0][0], 
                             'Couleur1.2': i[0][1],
                            'Couleur1.3' : i[0][2],
                             'Percentage1': i[5],
                            'Couleur2.1': i[1][0],
                            'Couleur2.2': i[1][1],
                            'Couleur2.3': i[1][2],
                            'Percentage2': i[6],
                            'Couleur3.1': i[2][0],
                            'Couleur3.2': i[2][1],
                            'Couleur3.3': i[2][2],
                            'Percentage3': i[7],
                            'Taille': i[3],
                           'Type1': i[8],
                           'Type2': i[9]})
    return

# %% [raw]
#  This cell will get the features from data and store it into a csv file

# %%
data = get_features_for_csv()
add_data_to_csv(data)

# %%
def get_pokemon_data(pokemon):
    reader = csv.reader(file, delimiter=',')
    for row in (reader):
        if(row[0][22:-4] == pokemon):
            return row

# %%
def search_color(r, g, b, R, G, B):

    Color = sRGBColor(r, g, b, is_upscaled = True)
    iteratedColor = sRGBColor(R, G, B, is_upscaled = True)

    #Processing color
    color1_lab = convert_color(Color, LabColor)

    color2_lab = convert_color(iteratedColor, LabColor)

    return delta_e_cie2000(color1_lab, color2_lab);

# %%
def is_matches(pokemondata, row, coef_delta_e, coef_percent, coef_size, delta_e_2, color_nb):
    if(delta_e < coef_delta_e):
                if(abs(int(row[13]) - int(pokemondata[13])) < coef_size):
                    if (abs(float(row[4*color_nb]) - float(pokemondata[4])) < coef_percent):
                        return True
    return False

# %%
def display_pokemon_searched(pokemondata):
    plt.figure()
    plt.imshow(mpimg.imread(pokemondata[0]))

# %%
def display_pokemon_found(pokemonFound):
    for i in range(len(pokemonFound)):
        plt.figure()
        plt.imshow(mpimg.imread(pokemonFound[i]))

# %%
file = open('data.csv', 'r')

pokemon = input("Select your favorite Pokemon ")

pokemonFound = []


print("Searching the Pokemon")

pokemondata = get_pokemon_data(pokemon)

        
file = open('data.csv', 'r')

reader = csv.reader(file, delimiter=',')
print("processing data")

coeff = 0

while len(pokemonFound) < 5:
    for row in (reader):
        #check if the pokemon is not the same
        if(row[0][22:-4] == pokemon):
            continue
            
        if(len(pokemonFound) > 5):
            break

        #Check if one type matches the pokemon
        elif(not(row[14] == pokemondata[14] or (row[15] == pokemondata[15] and row[15] != ""))):
            continue

        else:
            #Processing the first main color
            delta_e = search_color(float(pokemondata[1]), float(pokemondata[2]), float(pokemondata[3]),
                                  float(row[1]), float(row[2]), float(row[3]))
            
            #Processing the second main color
            delta_e_2 = search_color(float(pokemondata[5]), float(pokemondata[6]), float(pokemondata[7]),
                                    float(row[5]), float(row[6]), float(row[7]))
            
            #Processing the third main color
            delta_e_3 = search_color(float(pokemondata[9]), float(pokemondata[10]), float(pokemondata[11]),
                                    float(row[9]), float(row[10]), float(row[11]))
           
            coef_delta_e = coeff
            coef_size = 5*coeff
            coef_percent = 0.01 * coeff
            
            if(is_matches(pokemondata, row, coef_delta_e, coef_percent, coef_size, delta_e, 1)):
                pokemonFound.append(row[0])
                coeff+=5
            
            elif(is_matches(pokemondata, row, coef_delta_e, coef_percent, coef_size, delta_e_2, 2)):
                pokemonFound.append(row[0])
                coeff+=5
                
            elif(is_matches(pokemondata, row, coef_delta_e, coef_percent, coef_size, delta_e_3, 3)):
                pokemonFound.append(row[0])
                coeff+=5
                
            else:
                coeff+=5
           

display_pokemon_searched(pokemondata)       

display_pokemon_found(pokemonFound)
# Out:
# Select your favorite Pokemon arcanine
# Searching the Pokemon
# processing data
